# %% [markdown]
# # Mini projet Qualité de Données : Détections des doublons
# ## ***Christophe COMPAIN / Sander COHEN***

# %% [markdown]
# ### Objectif et Données Disponibles
# L'objectif du projet est d'identifier les logiciels vendus sur les deux plateformes.
#
# Pour ce faire, nous disposons des données pour chacune des plateformes isolément, respectivement dans les fichiers ***Company1.csv*** et ***Company2.csv***.

# %% [markdown]
# ### Import packages, Variables Globales et import csv

# %%
import pandas as pd
import nltk
import time
import numpy as np
import math
import re
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\scohe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\scohe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
path = "D:\\OneDrive - Université Paris-Dauphine\\Bureau\\Cours Master\\12-Qualité de Données\\\Projet\\mini-projet\\"
file1= "Data\\Company1.csv" #"SampleData\\Sample_Company1.csv"
file2= "Data\\Company2.csv" #"SampleData\\Sample_Company2.csv"
real= "Data\\Ground_truth_mappings.csv" #"SampleData\\Sample_Groud_truth_mappings.csv"

# %%
company1 = pd.read_csv(path+file1, encoding = "ISO-8859-1")
company2 = pd.read_csv(path+file2, encoding = "ISO-8859-1")
ground_truth_matches = pd.read_csv(path+real, encoding = "ISO-8859-1").drop_duplicates()

# %% [markdown]
# ### Exploration des données

# %%
company1.head(5)
# Out:
#            id                                              title  \
# 0  b000jz4hqo    clickart 950 000 - premier image pack (dvd-rom)
# 1  b0006zf55o   ca international - arcserve lap/desktop oem 30pk
# 2  b00004tkvy   noah's ark activity center (jewel case ages 3-8)
# 3  b000g80lqo  peachtree by sage premium accounting for nonpr...
# 4  b0006se5bq                            singing coach unlimited
#
#                                          description  \
# 0                                                NaN
# 1  oem arcserve backup v11.1 win 30u for laptops ...
# 2                                                NaN
# 3  peachtree premium accounting for nonprofits 20...
# 4  singing coach unlimited - electronic learning ...
#
#                 manufacturer   price
# 0                 broderbund    0.00
# 1        computer associates    0.00
# 2         victory multimedia    0.00
# 3              sage software  599.99
# 4  carry-a-tune technologies   99.99

# %%
company2.head(5)
# Out:
#                      id                                               name  \
# 0  11125907881740407428                           learning quickbooks 2007
# 1  11538923464407758599            superstart! fun with reading & writing!
# 2  11343515411965421256                          qb pos 6.0 basic software
# 3  12049235575237146821  math missions: the amazing arcade adventure (g...
# 4  12244614697089679523                     production prem cs3 mac upgrad
#
#                                          description    manufacturer   price
# 0                           learning quickbooks 2007          intuit   38.99
# 1  fun with reading & writing! is designed to hel...             NaN    8.49
# 2  qb pos 6.0 basic retail mngmt software. for re...          intuit  637.99
# 3  save spectacle city by disrupting randall unde...             NaN   12.95
# 4  adobe cs3 production premium mac upgrade from ...  adobe software  805.99

# %%
ground_truth_matches.head(5)
# Out:
#    idCompany1            idCompany2
# 0  b000jz4hqo  18441480711193821750
# 1  b00004tkvy  18441110047404795849
# 2  b000g80lqo  18441188461196475272
# 3  b0006se5bq  18428750969726461849
# 4  b00021xhzw  18430621475529168165

# %% [markdown]
# #### Observation d'un premier duplicat

# %%
company1[company1.id == ground_truth_matches.idCompany1[1]]
# Out:
#            id                                             title description  \
# 2  b00004tkvy  noah's ark activity center (jewel case ages 3-8)         NaN
#
#          manufacturer  price
# 2  victory multimedia    0.0

# %%
company2[company2.id == ground_truth_matches.idCompany2[1]]
# Out:
#                         id                                               name  \
# 1881  18441110047404795849  the beginners bible: noah's ark activity cente...
#
#      description manufacturer price
# 1881         NaN          NaN  9.95

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))  
stop_words.update(["r","v","software","entertainment","inc","usa"])

def prep(texte):
    #suppression des caracteres non alphanumériques + tout en minuscule
    texte = re.sub("[^a-zA-Z0-9_]", " ",str(texte)).lower()
    #remplacement de mots
    texte = texte.replace("professional", "pro").replace(" upg "," upgrade ").replace(" dlx "," deluxe ")
    #tokenization par mot
    tokens = nltk.word_tokenize(texte)
    #supreesion des stopwords
    filtered_tokens = [w for w in tokens if not w in stop_words]
#    # Stemming
#    texte = [nltk.stem.SnowballStemmer('english').stem(w) for w in filtered_tokens]
    # Lemmatization
    texte = [nltk.stem.WordNetLemmatizer().lemmatize(w) for w in filtered_tokens]
    #remise sous forme d'une string
    return " ".join(texte)

# %%
##retraitement des prix
def retreatprice(texte):
    #suppression des caracteres non alphanumériques + tout en minuscule
    return float(re.sub("[^0-9.]", " ",str(texte)))

# %%
company1['Company']="company1"
company1=company1.rename(columns={"title": "name"})
company1['name'] = company1['name'].fillna(' ')
company1['manufacturer'] = company1['manufacturer'].fillna(' ')
company1['description'] = company1['description'].fillna(' ')
company1['price'] = company1['price'].fillna(' ')
company1['price_retreat'] = company1['price'].apply(retreatprice)
company1['full data']=company1['manufacturer'].apply(prep) + ' ' + company1['name'].apply(prep) # + ' ' + company1['description'].apply(prep)

company2['Company']="company2"
company2['name'] = company2['name'].fillna(' ')
company2['manufacturer'] = company2['manufacturer'].fillna(' ')
company2['description'] = company2['description'].fillna(' ')
company2['price'] = company2['price'].fillna(' ')
company2['price_retreat'] = company2['price'].apply(retreatprice)
company2['full data']=company2['manufacturer'].apply(prep) + ' ' + company2['name'].apply(prep) # + ' ' + company2['description'].apply(prep)

# %%
corpus = pd.concat([company1, company2],sort=False,ignore_index=True)
#corpus.reset_index(drop=True)
len(corpus)
corpus.tail()
# Out:
#                         id                                            name  \
# 4584  14872602878188858026                 jumpstart(r) advanced 1st grade
# 4585  14916162814320983138          ibm(r) viavoice(r) advanced edition 10
# 4586  14974113209571399013                          xbox 360: gears of war
# 4587  14986935400648190776                     documents to go premium 7.0
# 4588  14996991014087320062  microsoft(r) picture it! digital image pro 9.0
#
#                                             description manufacturer  price  \
# 4584  prepare your child for the 1st grade and beyon...               19.99
# 4585  ibm viavoice advanced edition release 10 is a ...               78.95
# 4586  as marcus fenix you fight a war against the im...               59.99
# 4587  this pda software enables you to use your docu...               49.99
# 4588  picture it! digital image pro puts you in cont...               99.87
#
#        Company  price_retreat                                 full data
# 4584  company2          19.99              jumpstart advanced 1st grade
# 4585  company2          78.95          ibm viavoice advanced edition 10
# 4586  company2          59.99                         xbox 360 gear war
# 4587  company2          49.99                   document go premium 7 0
# 4588  company2          99.87   microsoft picture digital image pro 9 0

# %%
#recherche des mots unique pour les supprimer
allwords = corpus['full data'].str.split(expand=True).stack().value_counts()
stop_unique = set(allwords[allwords==1].index)

def prep2(texte):
    tokens = nltk.word_tokenize(texte)
    #supreesion des stopwords
    filtered_tokens = [w for w in tokens if not w in stop_unique]
    #remise sous forme d'une string
    return " ".join(filtered_tokens)

# %%
company1['full data']=company1['full data'].apply(prep2)
company2['full data']=company2['full data'].apply(prep2)

# %%
#company1_light = company1[company1['full data'].str.contains(filtre)].reset_index(drop=True)
#company2_light

# %%
###données punch software
filtre = "punch"
#stopwords_suppl =" software"
company1_light = company1[company1['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2[company2['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.5,sublinear_tf=True,stop_words=[filtre])#+stopwords_suppl]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

number_of_matches = 0
matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if  ((similarity > 0.35)) :#or jd_ng1_ng2_name<0.1 :# or name_score<=1) :
                number_of_matches = number_of_matches +1
                matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))
print("Number of matches: {}".format(number_of_matches))
matches_df = pd.DataFrame(matches)
matches_df.columns= ['idCompany1','idCompany2']
diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# Number of matches: 61
# Processing time: 0.34375
# Number of true positives: 31
# Number of false positives: 30
# Number of false negatives: 1269
# Precision: 0.5081967213114754
# Recall: 0.023846153846153847
# F measure: 0.0455547391623806

# %%
###données topics
filtre = "topic"
#stopwords_suppl =" entertainment"
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
company1_light = company1_light[company1_light['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2_light[company2_light['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.05,sublinear_tf=True,stop_words=[filtre]) #+stopwords_suppl]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if  ((similarity > 0.3)) or jd_ng1_ng2_name<0.2 :# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))
print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']
matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)

diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 51
# Total matches: 112
# Processing time: 0.9375
# Number of true positives: 61
# Number of false positives: 51
# Number of false negatives: 1239
# Precision: 0.5446428571428571
# Recall: 0.04692307692307692
# F measure: 0.08640226628895183

# %%
###données apple
filtre = "apple"
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
company1_light = company1_light[company1_light['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2_light[company2_light['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.1,sublinear_tf=True,stop_words=[filtre]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if  ((similarity > 0.4)) or jd_ng1_ng2_name<0.5 :# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))
print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']
matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)

diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 66
# Total matches: 178
# Processing time: 0.703125
# Number of true positives: 108
# Number of false positives: 70
# Number of false negatives: 1192
# Precision: 0.6067415730337079
# Recall: 0.08307692307692308
# F measure: 0.14614343707713126

# %%
###données Encore
filtre = "encore"
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
company1_light = company1_light[company1_light['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2_light[company2_light['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.01,sublinear_tf=True,stop_words=[filtre]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.2)) or jd_ng1_ng2_name<0.2 :# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))
print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']
matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)

diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 144
# Total matches: 322
# Processing time: 7.3125
# Number of true positives: 201
# Number of false positives: 121
# Number of false negatives: 1099
# Precision: 0.6242236024844721
# Recall: 0.15461538461538463
# F measure: 0.24784217016029597

# %%
###données Adobe
filtre = "adobe"
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
company1_light = company1_light[company1_light['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2_light[company2_light['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.5,sublinear_tf=True,stop_words=[filtre]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.6)) :# jd_ng1_ng2_name<0.3 :# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))
print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']
matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)

diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 91
# Total matches: 413
# Processing time: 4.15625
# Number of true positives: 251
# Number of false positives: 162
# Number of false negatives: 1049
# Precision: 0.6077481840193705
# Recall: 0.1930769230769231
# F measure: 0.29305312317571514

# %%
###données microsoft
filtre = "microsoft"
#stopwords_suppl =" software"
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
company1_light = company1_light[company1_light['full data'].str.contains(filtre)].reset_index(drop=True)
company2_light = company2_light[company2_light['full data'].str.contains(filtre)].reset_index(drop=True)
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.5,sublinear_tf=True,stop_words=[filtre]) #+stopwords_suppl]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
    try :  
        price1 = float(company1_light.iloc[i,6]) 
    except : 
        price1 = 0
    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
        try :  
            price2 = float(company2_light.iloc[j,6]) 
        except : 
            price2 = 0
        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.45)):# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))

print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']
matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
                
diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 73
# Total matches: 486
# Processing time: 4.140625
# Number of true positives: 285
# Number of false positives: 201
# Number of false negatives: 1015
# Precision: 0.5864197530864198
# Recall: 0.21923076923076923
# F measure: 0.3191489361702127

# %%
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,3), max_df=0.01,sublinear_tf=True)#,stop_words=["software"]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
#    try :  
    price1 = float(company1_light.iloc[i,6]) 
#    except : 
#        price1 = 0
#    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
#    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
#        try :  
        price2 = float(company2_light.iloc[j,6]) 
#        except : 
#            price2 = 0
#        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
#        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
#        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.5)):# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))



print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']


matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
#matches_df_temp = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
                
diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
#diff_df = pd.merge(ground_truth_matches, matches_df_temp, how='outer', indicator='Exist')


true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 678
# Total matches: 1164
# Processing time: 756.0
# Number of true positives: 724
# Number of false positives: 440
# Number of false negatives: 576
# Precision: 0.6219931271477663
# Recall: 0.556923076923077
# F measure: 0.5876623376623376

# %%
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.01,sublinear_tf=True)#,stop_words=["software"]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
#    try :  
    price1 = float(company1_light.iloc[i,6]) 
#    except : 
#        price1 = 0
#    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
#    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
#        try :  
        price2 = float(company2_light.iloc[j,6]) 
#        except : 
#            price2 = 0
#        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
#        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
#        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.5)):# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))



print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']


matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
###matches_df_temp = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
                
diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
###diff_df = pd.merge(ground_truth_matches, matches_df_temp, how='outer', indicator='Exist')


true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 163
# Total matches: 1206
# Processing time: 293.9375
# Number of true positives: 786
# Number of false positives: 420
# Number of false negatives: 514
# Precision: 0.6517412935323383
# Recall: 0.6046153846153847
# F measure: 0.627294493216281

# %%
company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

vectorizer = TfidfVectorizer(ngram_range=(1,1), max_df=0.01,sublinear_tf=True)#,stop_words=["software"]) #ngram_range=(1),
vectors = vectorizer.fit_transform(corpus['full data'])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()

new_number_of_matches = 0
new_matches=[]
start = time.process_time()
for i in range(len(company1_light)):
#    try :  
    price1 = float(company1_light.iloc[i,6]) 
#    except : 
#        price1 = 0
#    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
#    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
    for j in range(len(company2_light)):
#        try :  
        price2 = float(company2_light.iloc[j,6]) 
#        except : 
#            price2 = 0
#        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
#        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
#        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
            try :
                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
            except : 
                similarity = 0
            if ((similarity > 0.5)):# or name_score<=1) :
                new_number_of_matches = new_number_of_matches +1
                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))



print("New matches: {}".format(new_number_of_matches))
number_of_matches= number_of_matches + new_number_of_matches
print("Total matches: {}".format(number_of_matches))
new_matches_df = pd.DataFrame(new_matches)
new_matches_df.columns= ['idCompany1','idCompany2']


matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
###matches_df_temp = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
                
diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
###diff_df = pd.merge(ground_truth_matches, matches_df_temp, how='outer', indicator='Exist')


true_positives = diff_df[diff_df.Exist=='both']
false_positives = diff_df[diff_df.Exist=='right_only']
false_negatives = diff_df[diff_df.Exist=='left_only']
end = time.process_time()
print("Processing time: {}".format(end - start))
print("Number of true positives: {}".format(len(true_positives)))
print("Number of false positives: {}".format(len(false_positives)))
print("Number of false negatives: {}".format(len(false_negatives)))
precision = len(true_positives)/(len(true_positives)+ len(false_positives))
print("Precision: {}".format(precision))
recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
print("Recall: {}".format(recall))
f_measure = 2*(precision*recall)/(precision+recall)
print("F measure: {}".format(f_measure))
# Out:
# New matches: 297
# Total matches: 1503
# Processing time: 39.828125
# Number of true positives: 931
# Number of false positives: 572
# Number of false negatives: 369
# Precision: 0.6194278110445776
# Recall: 0.7161538461538461
# F measure: 0.6642882625758117

# %%
#company1_light=company1[~company1.id.isin(matches_df.idCompany1)]
#company2_light=company2[~company2.id.isin(matches_df.idCompany2)]
#corpus = pd.concat([company1_light, company2_light],sort=False,ignore_index=True)

# %%
#vectorizer = TfidfVectorizer(ngram_range=(1,1), max_df=0.01,sublinear_tf=True)#,stop_words=["software"]) #ngram_range=(1),
#vectors = vectorizer.fit_transform(corpus['full data'])
#feature_names = vectorizer.get_feature_names()
#dense = vectors.todense()

#new_number_of_matches = 0
#new_matches=[]
#start = time.process_time()
#for i in range(len(company1_light)):
##    try :  
#    price1 = float(company1_light.iloc[i,6]) 
##    except : 
##        price1 = 0
##    tokens1name = nltk.word_tokenize(company1_light.iloc[i,7])
##    ng1_tokensname = set(nltk.ngrams(tokens1name, n=1))
#    for j in range(len(company2_light)):
##        try :  
#        price2 = float(company2_light.iloc[j,6]) 
##        except : 
##            price2 = 0
##        tokens2name = nltk.word_tokenize(company2_light.iloc[j,7])
##        ng2_tokensname = set(nltk.ngrams(tokens2name, n=1))
##        jd_ng1_ng2_name = nltk.jaccard_distance(ng1_tokensname, ng2_tokensname)
#        if price1* price2 == 0 or max(price1, price2)/min(price1, price2)<2:
#            try :
#                similarity = np.dot(dense[i],np.transpose(dense[len(company1_light)+j])).item(0)/math.sqrt(np.dot(dense[i],np.transpose(dense[i])).item(0) * np.dot(dense[len(company1_light)+j],np.transpose(dense[len(company1_light)+j])).item(0))
#            except : 
#                similarity = 0
#            if ((similarity > 0.45)):# or name_score<=1) :
#                new_number_of_matches = new_number_of_matches +1
#                new_matches.append((company1_light.iloc[i,0],company2_light.iloc[j,0]))



#print("New matches: {}".format(new_number_of_matches))
#number_of_matches= number_of_matches + new_number_of_matches
#print("Total matches: {}".format(number_of_matches))
#new_matches_df = pd.DataFrame(new_matches)
#new_matches_df.columns= ['idCompany1','idCompany2']


###matches_df = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
#matches_df_temp = pd.concat([matches_df, new_matches_df],sort=False,ignore_index=True)
                
###diff_df = pd.merge(ground_truth_matches, matches_df, how='outer', indicator='Exist')
#diff_df = pd.merge(ground_truth_matches, matches_df_temp, how='outer', indicator='Exist')


#true_positives = diff_df[diff_df.Exist=='both']
#false_positives = diff_df[diff_df.Exist=='right_only']
#false_negatives = diff_df[diff_df.Exist=='left_only']
#end = time.process_time()
#print("Processing time: {}".format(end - start))
#print("Number of true positives: {}".format(len(true_positives)))
#print("Number of false positives: {}".format(len(false_positives)))
#print("Number of false negatives: {}".format(len(false_negatives)))
#precision = len(true_positives)/(len(true_positives)+ len(false_positives))
#print("Precision: {}".format(precision))
#recall = len(true_positives)/(len(true_positives)+ len(false_negatives))
#print("Recall: {}".format(recall))
#f_measure = 2*(precision*recall)/(precision+recall)
#print("F measure: {}".format(f_measure))

# %%
base_false_negatives =false_negatives.merge(corpus.loc[corpus['Company'] == 'company1']
                                            .drop(['Company','name','manufacturer'], inplace=False, axis=1)
                                            .rename(columns = {'id': 'idCompany1','description': 'descr1',
                                                               'price': 'price1','full data': 'full data1'}
                                                    , inplace = False)
                                            , how='inner', on='idCompany1').merge(corpus.loc[corpus['Company'] == 'company2']
                                                                                  .drop(['Company','name','manufacturer'], inplace=False, axis=1)
                                                                                  .rename(columns = {'id': 'idCompany2', 
                                                                                                     'description': 'descr2', 
                                                                                                     'price': 'price2', 
                                                                                                     'full data': 'full data2'}, inplace = False)
                                                                                  , how='inner', on='idCompany2')

# %%
base_false_positives =false_positives.merge(corpus.loc[corpus['Company'] == 'company1']
                                            .drop(['Company','name','manufacturer'], inplace=False, axis=1)
                                            .rename(columns = {'id': 'idCompany1','description': 'descr1',
                                                               'price': 'price1','full data': 'full data1'}
                                                    , inplace = False)
                                            , how='inner', on='idCompany1').merge(corpus.loc[corpus['Company'] == 'company2']
                                                                                  .drop(['Company','name','manufacturer'], inplace=False, axis=1)
                                                                                  .rename(columns = {'id': 'idCompany2', 
                                                                                                     'description': 'descr2', 
                                                                                                     'price': 'price2', 
                                                                                                     'full data': 'full data2'}, inplace = False)
                                                                                  , how='inner', on='idCompany2')

# %%
base_false_positives
# Out:
#      idCompany1            idCompany2       Exist  \
# 0    b00021xhzw   7972469902462196789  right_only
# 1    b00021xhzw   8148630564555070134  right_only
# 2    b000o26lo8   8148630564555070134  right_only
# 3    b000gzwjgc  18431827533263730235  right_only
# 4    b000083k56   5658005667319165691  right_only
# ..          ...                   ...         ...
# 147  b00006sijr   4579143769589006469  right_only
# 148  b00006sijr   1203903874013146755  right_only
# 149  b000ndicqi   2618959948842073817  right_only
# 150  b000ndicqi  18425990585802870010  right_only
# 151  b000ndicqi  13695802285127612231  right_only
#
#                                                 descr1  price1  \
# 0    upgrade only; installation of after effects st...  499.99
# 1    upgrade only; installation of after effects st...  499.99
# 2    note: this is the upgrade version of adobe aft...     299
# 3    - marketing information: dragon naturallyspeak...  399.54
# 4                                                            0
# ..                                                 ...     ...
# 147  the big story is flexibility and ease of use. ...  129.99
# 148  the big story is flexibility and ease of use. ...  129.99
# 149  note: this is the upgrade version of adobe fla...     199
# 150  note: this is the upgrade version of adobe fla...     199
# 151  note: this is the upgrade version of adobe fla...     199
#
#      price_retreat_x                                         full data1  \
# 0             499.99    adobe adobe effect pro 6 5 upgrade standard pro
# 1             499.99    adobe adobe effect pro 6 5 upgrade standard pro
# 2             299.00                     adobe adobe effect cs3 upgrade
# 3             399.54  nuance academic acad upgrade dragon naturallys...
# 4               0.00  compaq computer compaq comp secure path v3 0c ...
# ..               ...                                                ...
# 147           129.99     punch punch home design architectura series 18
# 148           129.99     punch punch home design architectura series 18
# 149           199.00              adobe adobe flash pro cs3 upgrade mac
# 150           199.00              adobe adobe flash pro cs3 upgrade mac
# 151           199.00              adobe adobe flash pro cs3 upgrade mac
#
#                                                 descr2      price2  \
# 0    system requirements powerpc® g4 or g5 or multi...      306.99
# 1    system requirements powerpc® g4 or g5 or multi...      329.99
# 2    system requirements powerpc® g4 or g5 or multi...      329.99
# 3                     voice recognition - english - pc      212.62
# 4    hp 231327-b22 : usually ships in 24 hours : : ...    65395.24
# ..                                                 ...         ...
# 147  we've taken our bestselling benchmark home des...      135.99
# 148  we've taken our bestselling benchmark home des...      135.99
# 149  system requirements 1ghz or faster powerpc g4 ...      239.99
# 150  adobe flash cs3 professional software is the m...  167.87 gbp
# 151  flash cs3 professional software is the most ad...         229
#
#      price_retreat_y                                         full data2
# 0             306.99                           adobe cs3 effect upgrade
# 1             329.99                          adobe cs3 effect academic
# 2             329.99                          adobe cs3 effect academic
# 3             212.62    nuance dragon naturallyspeaking 9 0 pro upgrade
# 4           65395.24  231327 b22 hp storageworks secure path netware...
# ..               ...                                                ...
# 147           135.99           punch punch 90500 home design studio mac
# 148           135.99           punch punch 90500 home design studio mac
# 149           239.99                       adobe cs3 flash pro academic
# 150           167.87  adobe flash cs3 v9 0 pro win flash pro basic a...
# 151           229.00  adobe flash cs3 pro complete package 1 user ac...
#
# [152 rows x 11 columns]

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option("max_rows", None)
base_false_negatives
# Out:
#      idCompany1            idCompany2      Exist  \
# 0    b00021xhzw  18430621475529168165  left_only
# 1    b00006hvvo  3409784122469217433   left_only
# 2    b00006hvvo  9687887699930800156   left_only
# 3    b00002sac9  8401993747038150345   left_only
# 4    b00009apna  3435680088823178198   left_only
# 5    b0009jlux8  4923451909983851979   left_only
# 6    b000cszg2m  5032391174084349054   left_only
# 7    b0002qnd2y  975032998818002648    left_only
# 8    b000cqyclu  1695089910833084773   left_only
# 9    b000bezsyi  10911853136488554482  left_only
# 10   b0001bg5gq  11618158047568311763  left_only
# 11   b000buqo9a  12604725900103506627  left_only
# 12   b000b6vlh4  10993073455692001778  left_only
# 13   b000cbqbby  5968511357343083164   left_only
# 14   b0000aka82  15883771067913561390  left_only
# 15   b0009ren8e  18152695793777845265  left_only
# 16   b000098xjo  16361312648941715869  left_only
# 17   b000314vvu  18384366678790095384  left_only
# 18   b0002e3g6o  18384557845547191313  left_only
# 19   b000099sin  18383594456090582739  left_only
# 20   b0000ak7c5  18424334149556003404  left_only
# 21   b000i84dsy  18427191929555331953  left_only
# 22   b000h774k0  18419564278412211145  left_only
# 23   b0006g2wke  18422068306669698354  left_only
# 24   b000ehq008  18415416380788323186  left_only
# 25   b0000c6fjm  18413075895200367717  left_only
# 26   b00005yx8i  18417819850768172148  left_only
# 27   b000hkgj8k  18417354130985846422  left_only
# 28   b0002719lk  18416093365515680633  left_only
# 29   b0006oei8u  18409822956112890125  left_only
# 30   b000i2qubi  12835181529749808477  left_only
# 31   b000056b62  18446496383812786183  left_only
# 32   b0006z16qq  18445827127704822533  left_only
# 33   b0006g31ao  18445341039052694828  left_only
# 34   b00005atxo  11430069725574750424  left_only
# 35   b000083k83  18439030063794622523  left_only
# 36   b0002bqqxw  18436194751131787997  left_only
# 37   b0006g2zce  16821958940203637711  left_only
# 38   b0000y7wc0  18438098517069192631  left_only
# 39   b00099qrok  9755705822363275907   left_only
# 40   b000bi7uqs  18403148885652932189  left_only
# 41   b0006g2wr2  18403352308945312678  left_only
# 42   b00063blg8  18399719239824156071  left_only
# 43   b0002bqrq8  18386073325514862606  left_only
# 44   b000aly75i  18391095906680955632  left_only
# 45   b000btas3y  18393736281334607132  left_only
# 46   b000bw7kxw  18392335669009428265  left_only
# 47   b000jgf410  9949258255997064102   left_only
# 48   b0000cg4ah  18417940197818815384  left_only
# 49   b000kzf7oo  18395554978346558556  left_only
# 50   b000hcxkks  18395554978346558556  left_only
# 51   b0002bqqtq  12603976278153658661  left_only
# 52   b000in18nm  12354599434001970846  left_only
# 53   b000qtu1ay  18391195855196917401  left_only
# 54   b000cqnjim  10662427062723563235  left_only
# 55   b000fzz73u  11404711258824251475  left_only
# 56   b000jgw9ae  10471177135649344162  left_only
# 57   b000nknb62  13773294714940805969  left_only
# 58   b00062ak2k  18376072611700638452  left_only
# 59   b0006g2vk0  18365507478568694929  left_only
# 60   b000oziaz8  15207825953028155236  left_only
# 61   b000fnevhk  18358728426530670777  left_only
# 62   b0006g2tum  18352674914916743912  left_only
# 63   b0007yepyg  14284530408597272725  left_only
# 64   b00032heyk  14100958400236899770  left_only
# 65   b000cbn9aa  13143355002649939201  left_only
# 66   b000922dwc  15297739858013318917  left_only
# 67   b000b0gzu8  14443748429238960679  left_only
# 68   b000ehpzxq  18381050378194058330  left_only
# 69   b000euhk3g  14356986779854403622  left_only
# 70   b000krd3bq  17596883596074762243  left_only
# 71   b000gwkol2  18376303388125635572  left_only
# 72   b000bnkbdm  18374143831267894200  left_only
# 73   b00009qenn  9685584718207146115   left_only
# 74   b0001h9l5m  15812045656958608251  left_only
# 75   b0007lw230  17298610841039937504  left_only
# 76   b000ndib7s  3473826515983580841   left_only
# 77   b000hbvvg4  4699273716641936158   left_only
# 78   b000cs3s2m  17504372812251027705  left_only
# 79   b00001xdw7  10541632718220382972  left_only
# 80   b0001wn1a8  8324654787720267662   left_only
# 81   b000hbxjt6  18387306349260922373  left_only
# 82   b00002s75b  18029245320668853953  left_only
# 83   b000mg2kpk  3907261301303045278   left_only
# 84   b000fmncb2  7928295573107692065   left_only
# 85   b000p5in5e  17334196774609191985  left_only
# 86   b000tilkpc  1081494753292983123   left_only
# 87   b000h6d2do  9639435771556038530   left_only
# 88   b000cqpc32  18386940331900923694  left_only
# 89   b000ujw3ss  3469210017983673758   left_only
# 90   b00081i6ji  18411096849519146392  left_only
# 91   b000kipk02  3911347389465432711   left_only
# 92   b000gcgqd2  6490413833919329208   left_only
# 93   b000edvrtq  14326164391298371952  left_only
# 94   b00009v3nw  16452108546715101414  left_only
# 95   b0000vyk1o  17409160117322953940  left_only
# 96   b000ecyp0k  3704829860217910239   left_only
# 97   b0002oqy1i  15832790434131694955  left_only
# 98   b000i8od48  3626343668255224722   left_only
# 99   b000fbgaia  30822033968544493     left_only
# 100  b00068u7ww  13815055497602261010  left_only
# 101  b0006nkbn2  13986409474793202514  left_only
# 102  b0000azk3v  8506958797516287357   left_only
# 103  b0000azk3v  5449819493015414043   left_only
# 104  b00007kh02  4749954713094759082   left_only
# 105  b00007kh02  7249154325906371083   left_only
# 106  b000cik6rc  18100341066456401733  left_only
# 107  b000h5fo8g  16987363527577090531  left_only
# 108  b000e13es0  16987363527577090531  left_only
# 109  b000nvspyo  17346668920138765245  left_only
# 110  b00013wh0w  341468719852005595    left_only
# 111  b00013wh0w  10202903815808902868  left_only
# 112  b00006gxbz  3767792591229692245   left_only
# 113  b000l1phg0  18394332776181186072  left_only
# 114  b000l1phg0  11954719051240282085  left_only
# 115  b000nknb8k  17333018247606173982  left_only
# 116  b0007zf3ge  10244573068939530333  left_only
# 117  b00006y0es  12445044163325859752  left_only
# 118  b000hbvvka  13394537834910060641  left_only
# 119  b000ik414i  16073556725854260285  left_only
# 120  b000230e4m  3000347833164648276   left_only
# 121  b0000vmimw  18364436159487312703  left_only
# 122  b000e8rdrq  890958699191814692    left_only
# 123  b000aqvrry  16846135635145492175  left_only
# 124  b0006ma3bs  16814254064816255791  left_only
# 125  b0000899lt  16676630267570211401  left_only
# 126  b000nkfee4  10699505690150129858  left_only
# 127  b00099xdpq  9660795325358759539   left_only
# 128  b000h1de00  17326098494894452732  left_only
# 129  b000bo9rt0  1187936019689259805   left_only
# 130  b0000959kx  6052848636732301170   left_only
# 131  b000o8gs3g  4395553239306869895   left_only
# 132  b000hhxeuo  1861020527779170726   left_only
# 133  b000bcicwa  12825336441689158397  left_only
# 134  b000ayxld4  13230504925826567019  left_only
# 135  b000fcyts2  14641221219676710452  left_only
# 136  b000bx441w  6376971851371386778   left_only
# 137  b0002vjvxy  15893880004435051441  left_only
# 138  b000aoz7jk  15423446152280840126  left_only
# 139  b000fbju6e  17104623549372310375  left_only
# 140  b000afkxso  1611810981921795487   left_only
# 141  b000j6ddrw  18190371164810858934  left_only
# 142  b000j6ddrw  18378133609675219667  left_only
# 143  b000lwfbem  6614738792097944479   left_only
# 144  b000edjjhs  17033785854482020785  left_only
# 145  b000h2can6  866471509127749885    left_only
# 146  b000ndid44  18415197771734313133  left_only
# 147  b0009affew  17165389585205797735  left_only
# 148  b000i3g30k  13078719460791292222  left_only
# 149  b000b6n2oe  848125606533600340    left_only
# 150  b000bdezfw  18431383104785501737  left_only
# 151  b000056b63  17180557293748751234  left_only
# 152  b000fc4du6  534612205120966482    left_only
# 153  b0009eu0ca  12931942175551075589  left_only
# 154  b000in8n30  11216712001773264822  left_only
# 155  b000in8n30  4377533611520192512   left_only
# 156  b0009jearq  17196507061828599304  left_only
# 157  b000gkxmea  17230198637846961402  left_only
# 158  b00008wiww  2096220602293961985   left_only
# 159  b000gamysk  17641037628832356751  left_only
# 160  b00004t2un  17501987182659378619  left_only
# 161  b000ndo7n0  17544063525352738794  left_only
# 162  b000egidpy  5558998293398547766   left_only
# 163  b000bgtvbc  15661314377252665074  left_only
# 164  b000fb9w3a  17941162981056466173  left_only
# 165  b000cs3s2c  17715266298340609214  left_only
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0    upgrade only; installation of after effects standard new disk caching tools speed up your interactive work save any combination of animation parameters as presets -- create transformations masks expressions effects and text tighter integration with other adobe tools - import photoshop cs and illustrator cs files with preserved layers and other attributes output to firewire for easier previewing on ntsc and pal video monitors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1    today enterprises and service providers face increasing security challenges in their distributed networks from security and virus attacks to enforcing security policies. as a distributed network grows and branches into multiple subnetworks linked by the internet so does the complexity of managing security appliances security policies and updates. a single flaw in security implementation at any point in the network can expose the entire infrastructure allowing malicious access to important data and files with severe consequences. managing security for distributed networks on a site-by-site basis is time consuming expensive and unreliable putting a big strain on already limited resources. sonicwall global management system (sonicwall gms) standard edition enables distributed enterprises and service providers to manage thousands of sonicwall internet security appliances from a central location with a powerful flexible and intuitive application. sonicwall gms delivers a cost-effective global security management solution that reduces staffing requirements speeds up deployment and lowers the cost of managing security services. sonicwall gms gives administrators the integrated tools to manage all security policies and services throughout a large-scale multiple policy enterprise or service provider environment. administrators can easily configure sonicwall firewall settings deploy vpn to any user and add sonicwall upgrade and subscription services such as gateway anti-virus anti-spyware and intrusion prevention service complete anti-virus and content filtering service with the click of a button.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 2    today enterprises and service providers face increasing security challenges in their distributed networks from security and virus attacks to enforcing security policies. as a distributed network grows and branches into multiple subnetworks linked by the internet so does the complexity of managing security appliances security policies and updates. a single flaw in security implementation at any point in the network can expose the entire infrastructure allowing malicious access to important data and files with severe consequences. managing security for distributed networks on a site-by-site basis is time consuming expensive and unreliable putting a big strain on already limited resources. sonicwall global management system (sonicwall gms) standard edition enables distributed enterprises and service providers to manage thousands of sonicwall internet security appliances from a central location with a powerful flexible and intuitive application. sonicwall gms delivers a cost-effective global security management solution that reduces staffing requirements speeds up deployment and lowers the cost of managing security services. sonicwall gms gives administrators the integrated tools to manage all security policies and services throughout a large-scale multiple policy enterprise or service provider environment. administrators can easily configure sonicwall firewall settings deploy vpn to any user and add sonicwall upgrade and subscription services such as gateway anti-virus anti-spyware and intrusion prevention service complete anti-virus and content filtering service with the click of a button.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 3    now featuring addition subtraction and counting to 30 the award-winning millie's math house has been enhanced to offer even more learning. in seven activities children explore numbers shapes sizes patterns addition and subtraction as they build mouse houses create wacky bugs count animated critters make jellybean cookies and answer math challenges posed by dorothy the duck. use the spanish language version for esl bilingual and spanish language instruction.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 4    the complete and easy publishing solution for your home orbusinessproduct informationentrust your business and personal publications to the renowned quality of theprint shop. backed by two decades of industry leadership this versatile programis an essenti                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 5    icopydvds2 pro edition contains all you need to copy a dvd movie quickly and easily. the interface is simple and direct just put in your movie press copy and icopydvds2 does the rest! our unique auto fit and auto burn technology creates the highest quality movie possible on a single disc every time!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 6    media made easy vol. 3 is your front-row ticket to enjoying the best of today's entertainment! powerful and easy to use it contains 8 full programs from some of the biggest names in entertainment software: roxio pinnacle steinberg & more. create record edit remix capture and restore -- media made easy vol. 3 does it all.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 7    customize your forms to your specific needs product information the complete solution for all of your business and personal form needs. selectfrom 1200 essential forms and letters customize the layout text and graphics or use the full suite of tools to create your own documents from scratch. a new simplified user interface quickly guides you though all of the highly advancedfeatures.&nbs                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# ...
# 78   adobe system flash remoting 1 0 net java 1 1 user
# 79   jumpstart kindergarten jc
# 80   microsoft microsoft office pro 2004 suite mac apple mac
# 81   intuit 299529 qb prem mfg whlesle 07 intuit 299529
# 82   microvision development webexpress
# 83   adobe photoshop lightroom
# 84   x plane 8 deluxe mac x graphic sim
# 85   mike garson andrew lloyd webber andrew lloyd webber favorite featuring sunset boulevard
# 86   global a8641jch dk smart step first grade win 95 98 2000 xp vista
# 87   global a9716jcw crossword addict win 95 98 2000 xp
# 88   avid liquid pro 7 0 video editing hardware bundle window pro editing
# 89   autodesk 3d max 9 3d animation window animation
# 90   adobe system adobe system 13102124 adobe photoshop c 2 mac x 10 2 8 10 3
# 91   adobe acrobat v8 0 pro mac academic
# 92   marketcircle daylite 3 customer relationship management crm
# 93   sony pc video game station access collection dvd rom
# 94   ea sport battlefield 1942 deluxe edition pc game
# 95   cyberlink power director 3
# 96   allume poser 6 mac
# 97   microsoft office 2004 suite oem mac apple mac
# 98   adobe acrobat v8 0 pro mac upgrade
# 99   computer associate babwbr1151s33 brightstor arcserve backup client snap shot 11 5 window service pack 1 add backup recovery 1 server complete product standard multilingual pc
# 100  east west propack garageband av production
# 101  hp hp t1936aa uao digital sending 4 0 10 device license
# 102  onone onone pxe 11433 pxl smartscale elect 1 user english mac win
# 103  onone onone pxe 11433 pxl smartscale elect 1 user english mac win
# 104  onone onone ice 10770 intellihance pro 4 1 mac win buy get free cs3 compatibility upgrade
# 105  onone onone ice 10770 intellihance pro 4 1 mac win buy get free cs3 compatibility upgrade
# 106  encore 10282 shark 2 0 win 95 98 2000 xp mac 10 1 higher
# 107  sony vega 6 video editing pro editing
# 108  sony vega 6 video editing pro editing
# 109  sony vegas7 0 dvd editing sound forge 8 window pro editing
# 110  palmspring palmspring 523 oxford american desk dictionary
# 111  palmspring palmspring 523 oxford american desk dictionary
# 112  global a1055 love win 95 98 nt 2000 xp mac 8 6 9 x classic x v10 1 higher
# 113  digital video audio prod book
# 114  sony creative digital video audio prod book
# 115  sony medium discrete drum vol 1 sony sound series
# 116  scrapbook designer platinum
# 117  century tt 1 century tinyterm 4 3x emulation 1 user english french german spanish italian polish portuguese pc
# 118  intuit qb po 6 0 pro solution hw sw
# 119  allume anime studio pro
# 120  mobi cam mobi cam 70008 monitoring notification
# 121  aspyr leave light bundle
# 122  adobe audition 2 0 audio production educational discount audio video
# 123  migo digital file shredder 2005
# 124  prosoft engineering data rescue universal license
# 125  topic talk afrikaans beginner
# 126  make songwriter music production
# 127  topic 40206 instant immersion german lab audiobook workbook win 98 2000 xp mac 9 x
# 128  make finale 2007 music production
# 129  encore 10392 network pro win 98 2000 xp
# 130  encore 25020 marine aquarium 2 5 hybrid win 95 98 2000 xp mac 10 1 higher
# 131  encore 12491 encore kissing canine screen saver
# 132  encore 11580 monopoly bonus risk win 98 2000 xp
# 133  allume stuffit deluxe 10 0 x 10 4 higher
# 134  aspyr roller coaster tycoon 3 mac x
# 135  zend studio 5 1 php integrated development environment
# 136  make printmusic 2006 music production
# 137  git comic book library collector edition vol 1
# 138  laughingbird flash ad creator
# 139  belight swift publisher page layout
# 140  make finale 2006 music production
# 141  allume smith micro faxstf pro
# 142  allume system stfmapbx2 faxstf pro
# 143  onone mpr 40211 on1 mask pro 4 0 complete product graphic designing 1 user complete product standard pc intel based mac mac
# 144  individual small business advantage deluxe
# 145  makemusic finale 2007 academic create edit print sheet music
# 146  adobe 38040450 dreamweaver cs3 complete product web development 1 user complete product academic universal english mac intel based mac
# 147  micromat diskstudio
# 148  microsoft money 2007 home business pc
# 149  aspyr stubbs zombie
# 150  adobe system 27910468 adobe framemaker 7 2 complete product desktop publishing 1 user complete product standard english pc plus 10 w ebillme free shipping
# 151  dvo enterprise cookn deluxe 6 0
# 152  sony medium acid pro 6 upgrade acid pro 5 music production
# 153  sony medium acid pro 5 music production
# 154  800801 hijack2 win 98 nt 2000 xp mac 10 0 higher
# 155  hijack2 identity data security suite
# 156  summitsoft corp photoedit 2
# 157  global marketing partner easy video editor 2 0 honest technology
# 158  spelling
# 159  emedia music corp guitar pro 5 1 hybrid
# 160  simply magazine sale skill
# 161  global marketing partner video patrol 5 0 honest technology
# 162  print master platinum v17
# 163  instant immersion translator deluxe 2 0
# 164  true north technology northstar
# 165  adobe system flash remoting 1 0 net java 2 2 user

# %%
['microsoft','adobe', 'apple']

# %%
pd.set_option("max_rows", None)
allwords
# Out:
# mac                           529
# 0                             504
# 1                             467
# win                           423
# pro                           421
# encore                        378
# microsoft                     373
# adobe                         365
# 2                             347
# 3                             298
# complete                      293
# user                          290
# pc                            280
# 5                             275
# window                        271
# edition                       268
# 2007                          253
# upgrade                       249
# license                       220
# xp                            193
# deluxe                        191
# 4                             191
# cd                            189
# medium                        188
# dvd                           187
# package                       166
# apple                         161
# punch                         160
# cs3                           157
# suite                         156
# 10                            153
# home                          153
# 6                             151
# 2000                          147
# 7                             141
# product                       141
# standard                      138
# music                         133
# server                        126
# production                    125
# topic                         124
# pack                          122
# studio                        122
# design                        121
# business                      119
# 98                            114
# 8                             114
# version                       110
# x                             102
# check                         101
# sony                           98
# game                           97
# system                         96
# 2006                           94
# premium                        90
# individual                     89
# video                          88
# yamaha                         80
# 9                              80
# freeverse                      78
# photoshop                      77
# adventure                      76
# symantec                       76
# guitar                         74
# abacus                         73
# emc                            73
# grade                          72
# c                              71
# global                         70
# instant                        70
# u                              69
# english                        68
# smart                          67
# plus                           67
# office                         66
# publishing                     66
# 11                             65
# quickbooks                     65
# audio                          65
# print                          63
# security                       63
# 2005                           62
# box                            62
# case                           62
# editing                        61
# year                           61
# w                              61
# card                           61
# digital                        60
# jewel                          60
# web                            58
# aspyr                          58
# school                         57
# client                         57
# subscription                   56
# learning                       56
# pianosoft                      55
# onone                          55
# interactive                    55
# peachtree                      53
# vista                          53
# creative                       53
# sonicwall                      52
# 2004                           52
# cisco                          52
# 2008                           51
# platinum                       51
# hoyle                          51
# development                    51
# homespun                       50
# collection                     50
# academic                       49
# enterprise                     49
# 3d                             49
# intuit                         49
# corel                          49
# sb                             48
# compatible                     48
# o                              47
# continuous                     47
# immersion                      46
# panda                          46
# webroot                        46
# internet                       45
# money                          45
# book                           44
# manager                        44
# world                          44
# per                            43
# backup                         43
# family                         43
# ibm                            42
# laser                          41
# premier                        41
# hp                             41
# emedia                         41
# teach                          41
# quicken                        41
# shop                           40
# small                          40
# computer                       40
# tm                             40
# accounting                     39
# math                           39
# play                           38
# 2003                           38
# final                          38
# linux                          38
# gold                           38
# corporation                    38
# technology                     37
# company                        37
# desktop                        37
# mnt                            37
# maker                          36
# rom                            36
# series                         36
# element                        36
# time                           35
# fogware                        35
# spy                            35
# nova                           34
# photo                          34
# corp                           34
# landscape                      34
# essential                      33
# 1u                             33
# management                     33
# advanced                       33
# advantage                      33
# service                        33
# higher                         32
# master                         32
# workshop                       32
# antivirus                      32
# bundle                         32
# anti                           32
# ssc                            31
# 01                             31
# typing                         31
# effect                         30
# data                           30
# 95                             30
# sage                           30
# educational                    30
# professor                      30
# mgr                            30
# express                        29
# 20                             29
# sound                          29
# success                        29
# csdc                           29
# 12                             29
# kit                            28
# steinberg                      28
# nt                             28
# acrobat                        28
# tool                           28
# spanish                        28
# ca                             28
# basic                          28
# set                            28
# 1st                            28
# marketing                      28
# lic                            27
# sibelius                       27
# simply                         27
# iii                            27
# network                        27
# premiere                       27
# full                           27
# ipod                           26
# super                          26
# movie                          26
# allume                         26
# agent                          26
# 1yr                            26
# training                       26
# watchguard                     26
# e                              26
# ultimate                       25
# additional                     25
# power                          25
# ed                             25
# war                            25
# project                        25
# std                            25
# zone                           25
# partner                        25
# cut                            24
# exec                           24
# protection                     24
# visual                         24
# flash                          24
# art                            24
# learn                          24
# svr                            24
# jumpstart                      24
# one                            24
# device                         24
# live                           24
# knowledge                      23
# word                           23
# kid                            23
# macintosh                      23
# 25                             23
# sa                             23
# vpn                            23
# 17                             23
# riverdeep                      23
# easy                           23
# logic                          23
# avanquest                      23
# l                              23
# architectural                  23
# architect                      23
# finance                        23
# preschool                      22
# ext                            22
# mcafee                         22
# image                          22
# form                           22
# mobile                         22
# unlimited                      22
# snap                           22
# cakewalk                       22
# arcserve                       22
# 100                            22
# broderbund                     22
# reader                         22
# star                           22
# gov                            22
# classic                        21
# sweeper                        21
# remote                         21
# hewlett                        21
# io                             21
# autodesk                       21
# leonard                        21
# best                           21
# ent                            21
# tycoon                         21
# aquarium                       21
# retail                         21
# expansion                      21
# lab                            21
# associate                      21
# 16                             21
# single                         21
# packard                        21
# tlp                            21
# creator                        21
# hal                            21
# kindergarten                   20
# tree                           20
# module                         20
# open                           20
# retrospect                     20
# engineering                    20
# v10                            20
# upsell                         20
# elementary                     20
# nintendo                       20
# big                            20
# piano                          20
# wasp                           20
# virus                          20
# nuance                         20
# communication                  19
# graphic                        19
# puzzle                         19
# llc                            19
# page                           19
# secure                         19
# playstation                    19
# ultra                          19
# 06                             19
# xbox                           19
# securid                        19
# sims                           19
# aggregation                    19
# brain                          19
# so                             19
# volume                         19
# support                        19
# firewall                       19
# h                              19
# solution                       19
# appl                           18
# pinnacle                       18
# destineer                      18
# norton                         18
# vega                           18
# option                         18
# ltd                            18
# auth                           18
# brighter                       18
# mind                           18
# total                          18
# 50                             17
# file                           17
# publisher                      17
# laptop                         17
# 360                            17
# act                            17
# mavis                          17
# roxio                          17
# hero                           17
# beacon                         17
# draft                          17
# netware                        17
# bible                          17
# authoring                      17
# base                           16
# av                             16
# computrace                     16
# free                           16
# d                              16
# lotus                          16
# tax                            16
# step                           16
# block                          16
# vol                            16
# microspot                      16
# finale                         16
# 3rd                            16
# picture                        16
# com                            16
# prm                            16
# lojack                         16
# disney                         16
# age                            16
# mini                           15
# host                           15
# multimedia                     15
# dk                             15
# magix                          15
# student                        15
# filemaker                      15
# cal                            15
# level                          15
# marine                         15
# explosion                      15
# collector                      15
# email                          15
# micromat                       15
# edu                            15
# middle                         15
# acid                           15
# spyware                        15
# transfer                       15
# blue                           15
# hit                            15
# ae                             15
# multi                          15
# universal                      15
# state                          14
# sudoku                         14
# g                              14
# excel                          14
# america                        14
# team                           14
# red                            14
# tlc                            14
# nero                           14
# alto                           14
# personal                       14
# plug                           14
# vmware                         14
# technique                      14
# insignia                       14
# phonics                        14
# new                            14
# arcade                         14
# high                           14
# masque                         14
# unix                           14
# 18                             14
# rumba                          14
# solitaire                      14
# nonprofit                      14
# john                           14
# palo                           14
# netmanage                      14
# limited                        14
# crystal                        14
# mike                           14
# jc                             14
# diskeeper                      14
# 22                             14
# disk                           13
# printmaster                    13
# library                        13
# micro                          13
# enfocus                        13
# monopoly                       13
# fish                           13
# capture                        13
# f                              13
# storage                        13
# avid                           13
# french                         13
# first                          13
# technical                      13
# id                             13
# method                         13
# envelope                       13
# builder                        13
# forge                          13
# language                       13
# 11d                            13
# ulead                          13
# ce                             13
# add                            13
# designer                       13
# pdf                            13
# fun                            13
# laplink                        13
# greatest                       13
# animation                      13
# b                              13
# v4                             13
# garson                         12
# plan                           12
# rock                           12
# r11                            12
# guide                          12
# v2                             12
# gatdef                         12
# 2nd                            12
# virtual                        12
# solaris                        12
# maintenance                    12
# valusoft                       12
# dreamweaver                    12
# screen                         12
# reading                        12
# three                          12
# casino                         12
# scrabble                       12
# object                         12
# brightstor                     12
# rabbit                         12
# ii                             12
# italian                        12
# dreamcatcher                   12
# cosmi                          12
# quick                          12
# 000                            12
# websphere                      12
# eng                            11
# make                           11
# backyard                       11
# psp                            11
# magic                          11
# factory                        11
# sonar                          11
# cubase                         11
# v9                             11
# date                           11
# gateway                        11
# later                          11
# genuine                        11
# legend                         11
# j                              11
# 4th                            11
# b21                            11
# 3yr                            11
# avery                          11
# printshop                      11
# corporate                      11
# education                      11
# performa                       11
# contact                        11
# flight                         11
# usb                            11
# drum                           11
# 0c                             11
# translator                     11
# blank                          11
# resumemaker                    11
# garageband                     11
# git                            11
# 2yr                            11
# bias                           11
# board                          11
# aec                            11
# truprevent                     11
# match                          11
# bridge                         11
# treasure                       11
# double                         11
# control                        11
# quest                          11
# discount                       11
# oem                            11
# hasbro                         11
# fractal                        11
# report                         11
# prod                           11
# atari                          11
# shipping                       11
# delorme                        10
# hallmark                       10
# iris                           10
# zonealarm                      10
# quickverse                     10
# extended                       10
# feral                          10
# 001                            10
# little                         10
# empire                         10
# developer                      10
# dictionary                     10
# node                           10
# intervideo                     10
# dragon                         10
# perfect                        10
# online                         10
# deal                           10
# strategy                       10
# washer                         10
# land                           10
# burning                        10
# workgroup                      10
# tune                           10
# center                         10
# addict                         10
# sec                            10
# absolute                       10
# taxcut                         10
# findex                         10
# ma                             10
# oxford                         10
# hand                           10
# multipurpose                   10
# reel                           10
# street                         10
# 250                            10
# x3                             10
# encyclopedia                   10
# conn                           10
# utility                        10
# specialty                      10
# path                           10
# pitstop                        10
# synergy                        10
# practical                      10
# tri                            10
# sw                             10
# imsi                           10
# century                        10
# action                         10
# sub                            10
# press                          10
# american                       10
# ipsec                          10
# national                       10
# 1000                           10
# sp2                            10
# song                           10
# aladdin                        10
# life                           10
# present                        10
# storageworks                   10
# v3                             10
# sale                            9
# german                          9
# ilife                           9
# mechanic                        9
# daceasy                         9
# msdn                            9
# indesign                        9
# zero                            9
# axis                            9
# v8                              9
# integration                     9
# britannica                      9
# researchsoft                    9
# illustrator                     9
# do                              9
# cable                           9
# jazz                            9
# pilot                           9
# liquid                          9
# gamecube                        9
# clickart                        9
# greeting                        9
# n                               9
# entupg                          9
# ip                              9
# day                             9
# phantom                         9
# sonic                           9
# great                           9
# camera                          9
# mod                             9
# dj                              9
# love                            9
# child                           9
# rescue                          9
# cs2                             9
# upg                             9
# scansoft                        9
# track                           9
# quark                           9
# 6th                             9
# net                             9
# workstation                     9
# amazing                         8
# le                              8
# based                           8
# v1                              8
# fw                              8
# enhanced                        8
# 8th                             8
# label                           8
# jam                             8
# bkup                            8
# po                              8
# go                              8
# geographic                      8
# viva                            8
# sunburst                        8
# oom                             8
# bling                           8
# combo                           8
# intel                           8
# sim                             8
# procurve                        8
# recovery                        8
# isi                             8
# converter                       8
# hunter                          8
# access                          8
# vivendi                         8
# renewal                         8
# international                   8
# sea                             8
# david                           8
# consumer                        8
# lb                              8
# readiris                        8
# care                            8
# tony                            8
# reference                       8
# wild                            8
# 500                             8
# sport                           8
# efx                             8
# kakuro                          8
# lick                            8
# clue                            8
# extensis                        8
# pirate                          8
# lego                            8
# put                             8
# hd                              8
# drive                           8
# fuji                            8
# portal                          8
# dvo                             8
# videostudio                     8
# ltu                             8
# animal                          8
# artist                          8
# sega                            8
# powerpoint                      8
# deck                            8
# update                          8
# bus                             8
# soft                            8
# elegant                         8
# simple                          8
# slot                            8
# copy                            8
# activision                      8
# topware                         8
# processor                       8
# return                          8
# registry                        8
# civilization                    8
# netopia                         8
# bass                            8
# rainbow                         8
# point                           8
# study                           8
# molpc                           8
# warcraft                        8
# crm                             8
# 101                             8
# steve                           8
# sp1                             7
# orchestra                       7
# galaxy                          7
# activity                        7
# 400                             7
# application                     7
# hudson                          7
# titanium                        7
# prosoft                         7
# competitive                     7
# ov                              7
# smith                           7
# hat                             7
# qb                              7
# prem                            7
# 2002                            7
# safe                            7
# 24x7                            7
# process                         7
# monkey                          7
# tiger                           7
# pop                             7
# simulation                      7
# film                            7
# solo                            7
# recording                       7
# federal                         7
# firebox                         7
# call                            7
# poser                           7
# mv                              7
# made                            7
# keveren                         7
# na                              7
# sys                             7
# dantz                           7
# en                              7
# large                           7
# myob                            7
# white                           7
# phillip                         7
# sbe                             7
# interface                       7
# let                             7
# wingnuts                        7
# sat                             7
# identity                        7
# iwork                           7
# inkjet                          7
# scrapbook                       7
# shark                           7
# diamond                         7
# extreme                         7
# site                            7
# active                          7
# weekly                          7
# mappoint                        7
# cinema                          7
# navarre                         7
# jce                             7
# instrument                      7
# 21                              7
# 8200                            7
# jungle                          7
# phase                           7
# psat                            7
# stuffit                         7
# cf                              7
# visio                           7
# japanese                        7
# epson                           7
# code                            7
# honest                          7
# christmas                       7
# selectsoft                      7
# xi                              7
# core                            7
# use                             7
# mariner                         7
# science                         7
# soundtrack                      7
# testing                         6
# versacheck                      6
# route                           6
# practice                        6
# poker                           6
# marvel                          6
# electric                        6
# group                           6
# architecture                    6
# distiller                       6
# cad                             6
# instructor                      6
# got                             6
# mpr                             6
# motu                            6
# monarch                         6
# revenge                         6
# south                           6
# soundbooth                      6
# 90                              6
# csf                             6
# deposit                         6
# starter                         6
# wireless                        6
# cranium                         6
# makemusic                       6
# mainframe                       6
# launch                          6
# synet                           6
# tier                            6
# legal                           6
# skill                           6
# 7th                             6
# house                           6
# clifford                        6
# quickeys                        6
# wn5                             6
# allegro                         6
# 3des                            6
# payroll                         6
# mu                              6
# plane                           6
# ez                              6
# saver                           6
# neil                            6
# scholastic                      6
# deployment                      6
# upgr                            6
# 5k                              6
# lfl                             6
# timbuktu                        6
# tiny                            6
# old                             6
# boxed                           6
# night                           6
# view                            6
# ubi                             6
# serious                         6
# clean                           6
# audition                        6
# director                        6
# stomp                           6
# test                            6
# appliance                       6
# iv                              6
# notebook                        6
# organizer                       6
# dr                              6
# living                          6
# explorer                        6
# chronos                         6
# mission                         6
# lesson                          6
# aircraft                        6
# bird                            6
# smartscale                      6
# z                               6
# terminal                        6
# resume                          6
# vhs                             6
# god                             6
# moviefactory                    6
# govt                            6
# bob                             6
# calendar                        6
# gorilla                         6
# novell                          6
# on1                             6
# kutoka                          6
# 004                             6
# mask                            6
# link                            6
# bang                            6
# north                           6
# king                            6
# logo                            6
# painter                         6
# non                             6
# san                             6
# writing                         6
# line                            6
# download                        6
# various                         6
# replicator                      6
# 006                             6
# slip                            6
# tonka                           6
# james                           6
# original                        6
# k9                              6
# mobileinventory                 6
# pk                              6
# search                          6
# partition                       6
# psg                             6
# symc                            6
# history                         6
# fax                             6
# 5u                              6
# bar                             6
# x4                              6
# agreement                       5
# magnetic                        5
# edit                            5
# starry                          5
# sg                              5
# stompsoft                       5
# sierra                          5
# bluegrass                       5
# immers                          5
# edius                           5
# hardware                        5
# ub                              5
# praise                          5
# delphi                          5
# magellan                        5
# xl                              5
# dev                             5
# emulator                        5
# 250u                            5
# v6                              5
# paperport                       5
# dv                              5
# risk                            5
# victory                         5
# 15                              5
# style                           5
# man                             5
# scene                           5
# 251                             5
# sportsman                       5
# clip                            5
# dynamic                         5
# teacher                         5
# intellihance                    5
# font                            5
# karaoke                         5
# fimm                            5
# fed                             5
# ux                              5
# hummingbird                     5
# dan                             5
# namco                           5
# belight                         5
# iview                           5
# turbocad                        5
# cleanup                         5
# rising                          5
# requirement                     5
# v                               5
# traum                           5
# ipswitch                        5
# iplaymusic                      5
# simulator                       5
# west                            5
# quarkxpress                     5
# 005                             5
# programming                     5
# shirt                           5
# 70                              5
# color                           5
# work                            5
# valley                          5
# mystery                         5
# city                            5
# modern                          5
# mapping                         5
# 500u                            5
# srvr                            5
# atlas                           5
# infrastructure                  5
# t74                             5
# intermediate                    5
# pagemaker                       5
# webber                          5
# kaspersky                       5
# xpress                          5
# 2001                            5
# 30                              5
# smb                             5
# exch                            5
# special                         5
# slide                           5
# 2k                              5
# ableton                         5
# tournament                      5
# banjo                           5
# fs2002                          5
# datawatch                       5
# 150                             5
# windvd                          5
# lightroom                       5
# spongebob                       5
# kaplan                          5
# mastering                       5
# food                            5
# virusscan                       5
# mobi                            5
# 3000                            5
# rhythm                          5
# 200                             5
# club                            5
# exceed                          5
# csa                             5
# ally                            5
# viavoice                        5
# mile                            5
# datapilot                       5
# light                           5
# v5                              5
# peak                            5
# zetafax                         5
# safekeeper                      5
# 20100                           5
# sue                             5
# customer                        5
# interior                        5
# beginner                        5
# operation                       5
# intego                          5
# eovia                           5
# outlook                         5
# susteen                         5
# designing                       5
# tinyterm                        5
# sharing                         5
# naturallyspeaking               5
# keyboard                        5
# photostory                      5
# alfred                          5
# olp                             5
# sonicfire                       5
# mediafour                       5
# pocket                          5
# wii                             5
# baby                            5
# pcanywhere                      5
# macsoft                         5
# gm                              5
# webexp                          5
# beyond                          5
# fs2004                          5
# onenote                         5
# duty                            5
# doctor                          5
# topo                            5
# mediapro                        5
# bonus                           5
# dance                           5
# cluefinders                     5
# assurance                       5
# arthur                          5
# storyboard                      5
# pix                             5
# isa                             5
# mix                             5
# jeopardy                        5
# real                            5
# slm                             5
# trio                            5
# 902453                          5
# b26                             4
# binder                          4
# annual                          4
# theme                           4
# publ                            4
# dinosaur                        4
# start                           4
# hw                              4
# sticker                         4
# ringtone                        4
# body                            4
# raina                           4
# firework                        4
# farm                            4
# clt                             4
# rise                            4
# wheel                           4
# totally                         4
# lancer                          4
# jackson                         4
# p                               4
# trend                           4
# 5000                            4
# kensington                      4
# canopus                         4
# 14100                           4
# grant                           4
# 40212                           4
# fingerstyle                     4
# mindjet                         4
# happy                           4
# th6                             4
# systemsuite                     4
# expression                      4
# emulation                       4
# cals                            4
# ml                              4
# 9x5                             4
# zombie                          4
# low                             4
# buddy                           4
# leisure                         4
# create                          4
# dog                             4
# gaming                          4
# recipe                          4
# jboss                           4
# show                            4
# approach                        4
# 2d                              4
# lnx                             4
# router                          4
# imagination                     4
# fontware                        4
# cillin                          4
# nuw45e1k                        4
# techtool                        4
# universe                        4
# 38100                           4
# shape                           4
# ops                             4
# guild                           4
# wavelab                         4
# post                            4
# 50u                             4
# macdraft                        4
# mega                            4
# planmaker                       4
# 1000u                           4
# stopzilla                       4
# quickstart                      4
# warlord                         4
# model                           4
# creating                        4
# anniversary                     4
# imaginova                       4
# 8m                              4
# keith                           4
# two                             4
# dvdrom                          4
# digidesign                      4
# 35100                           4
# ue                              4
# workbook                        4
# ws_ftp                          4
# career                          4
# get                             4
# ad                              4
# squarepants                     4
# rich                            4
# chicken                         4
# 900                             4
# remoting                        4
# humongous                       4
# elite                           4
# v11                             4
# room                            4
# 4001                            4
# eagle                           4
# comic                           4
# millionaire                     4
# 25100                           4
# east                            4
# fundamental                     4
# serverlock                      4
# montage                         4
# buy                             4
# shrinkwrap                      4
# deere                           4
# solver                          4
# ledger                          4
# d51rsll                         4
# amy                             4
# fraction                        4
# coaster                         4
# producer                        4
# phone                           4
# combat                          4
# racing                          4
# true                            4
# basketball                      4
# ghost                           4
# extend                          4
# bee                             4
# donny                           4
# dora                            4
# db2                             4
# 40                              4
# town                            4
# alliance                        4
# turbo                           4
# beginning                       4
# k                               4
# region                          4
# 4024                            4
# andrew                          4
# quake                           4
# place                           4
# davis                           4
# sp                              4
# general                         4
# superstart                      4
# 4012                            4
# park                            4
# academy                         4
# iolo                            4
# northland                       4
# aquazone                        4
# iseries                         4
# chesster                        4
# antispam                        4
# 66                              4
# traktor                         4
# compaq                          4
# blizzard                        4
# analyzer                        4
# creativity                      4
# sup                             4
# compatibility                   4
# casual                          4
# diana                           4
# macdrive                        4
# robin                           4
# lloyd                           4
# taylor                          4
# portfolio                       4
# alsoft                          4
# pmm                             4
# spelling                        4
# playing                         4
# comp                            4
# cook                            4
# rome                            4
# uk                              4
# station                         4
# lynyrd                          4
# concept                         4
# 54210                           4
# 010                             4
# 7356                            4
# licen                           4
# zoo                             4
# crime                           4
# enterasys                       4
# ocean                           4
# win32                           4
# engli                           4
# today                           4
# symphonic                       4
# coreldraw                       4
# ghostsurf                       4
# hot                             4
# productcomplete                 4
# merchant                        4
# veritas                         4
# safari                          4
# sql                             4
# human                           4
# wordperfect                     4
# mass                            4
# recorder                        4
# novanet                         4
# popcorn                         4
# migo                            4
# 400pt                           4
# adv                             4
# cross                           4
# alan                            4
# season                          4
# 4015                            4
# includes                        4
# paul                            4
# berklee                         4
# hyb                             4
# redshift                        4
# museum                          4
# seuss                           4
# 17100                           4
# productstandard                 4
# lead                            4
# solace                          4
# texas                           4
# ftp                             4
# lt                              4
# oil                             4
# cast                            4
# patrol                          4
# fortune                         4
# goldfish                        4
# mahjongg                        4
# million                         4
# skynyrd                         4
# mlp                             4
# rational                        4
# keepsake                        4
# rce                             4
# n2                              4
# 4100                            4
# acad                            4
# writer                          4
# thq                             4
# nikon                           4
# fritz                           4
# brother                         4
# learn2                          4
# zonelabs                        4
# compositing                     4
# 5563                            4
# carrara                         4
# 3001                            4
# cookn                           4
# bit                             4
# pxl                             4
# checkmark                       4
# 42100                           4
# gps                             4
# 10000                           4
# machine                         4
# bach                            4
# screenwriting                   4
# connectivity                    4
# larry                           4
# chess                           4
# 41100                           4
# ingres                          4
# shake                           4
# soloing                         4
# band                            4
# musical                         4
# fasttrack                       4
# pgw2200                         4
# 00                              4
# judy                            4
# max                             4
# f89                             4
# presentation                    4
# palmspring                      4
# borland                         4
# schedule                        4
# hood                            4
# vsi                             4
# idol                            4
# caillou                         4
# boomerang                       4
# wanted                          4
# ilisten                         4
# expert                          4
# efile                           4
# cell                            4
# wi                              4
# 65210                           4
# mail                            4
# battle                          4
# train                           4
# anime                           4
# wacky                           4
# managed                         4
# yr                              4
# crossgrade                      4
# pasqua                          4
# palm                            4
# xg                              4
# esk9                            4
# 26100                           4
# a01                             3
# plat                            3
# might                           3
# jay                             3
# appleworks                      3
# macjournal                      3
# spider                          3
# mathra                          3
# chessmaster                     3
# shell                           3
# radio                           3
# cust                            3
# database                        3
# ...
# chorus                          1
# fl37                            1
# qx                              1
# crosspicking                    1
# curtis                          1
# 11290                           1
# xw                              1
# 77010158100                     1
# trellian                        1
# operating                       1
# boohbah                         1
# uao                             1
# 23102459dg                      1
# santana                         1
# babyz                           1
# uml                             1
# swingin                         1
# bps                             1
# complet                         1
# twilight                        1
# backbeat                        1
# 27100                           1
# 00132                           1
# mias                            1
# crackdown                       1
# 641604                          1
# forza                           1
# 9780201767919                   1
# willy                           1
# 50411                           1
# misc                            1
# carbon                          1
# c32011                          1
# 00473                           1
# 01002                           1
# rtu                             1
# 10075                           1
# ntracker                        1
# mch                             1
# nuvi                            1
# 20005                           1
# rtl                             1
# 1tb                             1
# holman                          1
# bernard                         1
# asams7000                       1
# kb37                            1
# everett                         1
# bu24a600000                     1
# eva                             1
# 1950824l1                       1
# 0787731062117                   1
# synercard                       1
# 00dexx17cc01                    1
# edbuua61c                       1
# 6791                            1
# 950k                            1
# 6sb                             1
# wwii                            1
# lin                             1
# 25510587                        1
# driver                          1
# george                          1
# 3060                            1
# 900000u                         1
# 5695                            1
# trip                            1
# 10450                           1
# vk                              1
# 7738                            1
# mode                            1
# 12491                           1
# 57408                           1
# 284216                          1
# baltica                         1
# mar                             1
# songbook                        1
# dja                             1
# wmedia                          1
# icon                            1
# alphabet                        1
# mimi                            1
# 633808106058                    1
# entmnt                          1
# m8789z                          1
# 50210                           1
# cello                           1
# 11431                           1
# req                             1
# 33024                           1
# innata                          1
# 59j                             1
# 22070152                        1
# roadmaps                        1
# 11750                           1
# vernfp2008rt                    1
# ejay                            1
# finest                          1
# kitten                          1
# insert                          1
# stage                           1
# sd820                           1
# j8990a                          1
# 5325301871                      1
# 13102124                        1
# extrn                           1
# 28                              1
# 3363                            1
# malveau                         1
# 38040450                        1
# tv                              1
# 00250                           1
# univeral                        1
# sp32i570001m1100p               1
# extrnlconnnonemplyenglands      1
# app0003500bs8                   1
# context                         1
# 10478                           1
# beatles                         1
# 1pk                             1
# 9331                            1
# b7305pa                         1
# unixware                        1
# 1260                            1
# 9000mfp                         1
# cadtprnaen150                   1
# 17530402                        1
# distributed                     1
# aut0000750ue15                  1
# elic                            1
# xx                              1
# 781735805428                    1
# rom03558                        1
# sngl                            1
# glossy                          1
# bablur1150s06                   1
# 10328                           1
# 9912231                         1
# journal                         1
# schl                            1
# 6002                            1
# f309a                           1
# 12411                           1
# k2                              1
# groovy                          1
# episode                         1
# leister                         1
# gf6                             1
# brengle                         1
# 1979                            1
# wg017449                        1
# whiptail                        1
# quantity                        1
# 00101                           1
# feel                            1
# 20u                             1
# flashcopy                       1
# af                              1
# statistical                     1
# 13871                           1
# katamari                        1
# c32028                          1
# copydvds                        1
# 11272                           1
# a3pgdpbwfh                      1
# applicator                      1
# hostexplorer                    1
# 11281445                        1
# volumecopy                      1
# documenting                     1
# int                             1
# ppi                             1
# 641634                          1
# 10356                           1
# pixar                           1
# 9783540626954                   1
# hgw                             1
# rom07524                        1
# 00063                           1
# vwscwwe6xybupn                  1
# 13791                           1
# allows                          1
# 0636430024974                   1
# 42001                           1
# mickey                          1
# incopy                          1
# a8641jch                        1
# conf                            1
# min                             1
# a590a                           1
# 10294                           1
# u0200024                        1
# a0447jch                        1
# bosendorfer                     1
# nbcn1005                        1
# fujitsu                         1
# cns                             1
# hoban                           1
# paint                           1
# warsaw                          1
# charting                        1
# app0001500ue22                  1
# compiler                        1
# 00487                           1
# replistor                       1
# fretboard                       1
# 10282                           1
# scientific                      1
# laserjet                        1
# 400e                            1
# 6900                            1
# t3840aa                         1
# gmp                             1
# studyworks                      1
# winvista                        1
# virtuoso                        1
# 1980                            1
# ezran                           1
# 11105972                        1
# victorymul                      1
# qrkxppsptversion7               1
# hour                            1
# 1gb                             1
# 38039295dm                      1
# usoa289                         1
# primavera                       1
# 1460                            1
# 00001                           1
# 17m                             1
# wg017310                        1
# 1ltu                            1
# e17886d                         1
# 10517904                        1
# luxor                           1
# 72212                           1
# 75                              1
# horse                           1
# 140gb                           1
# london                          1
# ue1u                            1
# prw                             1
# ubisoft                         1
# 10675                           1
# dsk                             1
# 5325301873                      1
# n10                             1
# xbrace                          1
# plc                             1
# php                             1
# proed                           1
# esd                             1
# diy                             1
# 0093156011006                   1
# 10547845                        1
# hedgehog                        1
# peace                           1
# 22030094                        1
# sygate                          1
# 50000                           1
# 433691                          1
# 25000                           1
# 5wkst                           1
# wizooverb                       1
# 81499                           1
# bacharach                       1
# latin                           1
# ints3                           1
# haug                            1
# 750                             1
# rcm500k                         1
# johannes                        1
# unit                            1
# magstripe                       1
# 14111                           1
# snt                             1
# 501926                          1
# gc                              1
# americana                       1
# macxware                        1
# input                           1
# 00144                           1
# 12225sg                         1
# mortal                          1
# 633808920357                    1
# cmp                             1
# t76                             1
# upgrd                           1
# mainte                          1
# courseware                      1
# 00892                           1
# resco                           1
# 23500195dm                      1
# mediterranean                   1
# 870                             1
# 00369                           1
# outdoor                         1
# tapestry                        1
# up04003j                        1
# movieboard                      1
# 400p                            1
# rated                           1
# interplay                       1
# 1998                            1
# jig                             1
# 11610                           1
# mania                           1
# svrless                         1
# systematic                      1
# fine                            1
# appleloops                      1
# 9780201754544                   1
# kaisler                         1
# yu                              1
# carry                           1
# beloff                          1
# 808                             1
# 2500u                           1
# wg017285                        1
# mpk                             1
# imagemanager                    1
# fee                             1
# 413115                          1
# 36123                           1
# wholesale                       1
# salvage                         1
# pham                            1
# 10612                           1
# registrar                       1
# 11861                           1
# wolf                            1
# bb0lgml                         1
# smartmusic                      1
# advance                         1
# 10561                           1
# 9781580535083                   1
# sbg900                          1
# 12371                           1
# rtailrs                         1
# verderosa                       1
# universa                        1
# ua037                           1
# 22002170                        1
# 10603                           1
# pbupgrd                         1
# recordnow                       1
# 00846                           1
# kinder                          1
# survey                          1
# hotrod                          1
# christine                       1
# 10114                           1
# schoolhouse                     1
# workgroups                      1
# pretzel                         1
# 9780133056990                   1
# aut0000250ee8                   1
# keystation                      1
# 600                             1
# retial                          1
# bqcpd                           1
# samplitude                      1
# colour                          1
# paradigm                        1
# disc                            1
# c1u                             1
# ipx                             1
# 100r                            1
# ra                              1
# manufactured                    1
# cert                            1
# esd1                            1
# aut0005000bs22                  1
# altair                          1
# chang                           1
# 01685                           1
# 12360                           1
# ae7ntna                         1
# 17410                           1
# podmediacreator                 1
# streaming                       1
# 00ids510cc                      1
# 10bt                            1
# 100000                          1
# urban                           1
# extrnlconnnonemplyengl          1
# cs1                             1
# 01256                           1
# babwbr1151s33                   1
# 9999                            1
# doug                            1
# 9780521337861                   1
# dream                           1
# procoder                        1
# pictureproject                  1
# assr                            1
# porter                          1
# melody                          1
# fifa                            1
# exmpi556001m1200p               1
# stop                            1
# flexnet                         1
# chainz                          1
# brtr                            1
# rf                              1
# load                            1
# 17911                           1
# 19500220                        1
# tsb1310wwfs180                  1
# b2prse6f                        1
# generator                       1
# nft1250                         1
# fpxmlc020                       1
# zealand                         1
# mat                             1
# burt                            1
# kosek                           1
# 14mo                            1
# 19250096dg                      1
# 10101090220000101               1
# lava                            1
# 38039926                        1
# uea                             1
# b67                             1
# bootcamp                        1
# de905                           1
# 00360                           1
# eq771av                         1
# raritan                         1
# 12070227                        1
# eg04025                         1
# seeing                          1
# 10634                           1
# acdsee                          1
# billiards                       1
# mpd9                            1
# garfield                        1
# containing                      1
# sabrina                         1
# 2007for                         1
# session                         1
# pocketpc                        1
# flashpaper                      1
# 9780471483472                   1
# asure                           1
# 11888479                        1
# 11430                           1
# directory                       1
# oscar                           1
# ingram                          1
# huttlinger                      1
# loss                            1
# vin                             1
# endusers                        1
# 10602                           1
# klopfenstein                    1
# ope                             1
# 10158                           1
# carey                           1
# 72305                           1
# weapon                          1
# de                              1
# harmony                         1
# 10r                             1
# 23m                             1
# adva                            1
# 11052                           1
# plant                           1
# sweet                           1
# sgms                            1
# cathal                          1
# dtype: int64
